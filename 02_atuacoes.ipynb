# %% [markdown]
# ## Etapa 1 - Instalação de Bibliotecas necessárias

# %%
# %pip install pandas
# %pip install matplotlib.pyplot
# %pip install seaborn
# Out:
# Requirement already satisfied: pandas in c:\users\camil\onedrive\documentos\cientometria_projeto\.venv\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\camil\onedrive\documentos\cientometria_projeto\.venv\lib\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\camil\onedrive\documentos\cientometria_projeto\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\camil\onedrive\documentos\cientometria_projeto\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\camil\onedrive\documentos\cientometria_projeto\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\camil\onedrive\documentos\cientometria_projeto\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement matplotlib.pyplot (from versions: none)
# ERROR: No matching distribution found for matplotlib.pyplot
# Requirement already satisfied: seaborn in c:\users\camil\onedrive\documentos\cientometria_projeto\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\camil\onedrive\documentos\cientometria_projeto\.venv\lib\site-packages (from seaborn) (2.2.6)
# Requirement already satisfied: pandas>=1.2 in c:\users\camil\onedrive\documentos\cientometria_projeto\.venv\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\camil\onedrive\documentos\cientometria_projeto\.venv\lib\site-packages (from seaborn) (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\camil\onedrive\documentos\cientometria_projeto\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\camil\onedrive\documentos\cientometria_projeto\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\camil\onedrive\documentos\cientometria_projeto\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\camil\onedrive\documentos\cientometria_projeto\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\camil\onedrive\documentos\cientometria_projeto\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\camil\onedrive\documentos\cientometria_projeto\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\camil\onedrive\documentos\cientometria_projeto\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\camil\onedrive\documentos\cientometria_projeto\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\camil\onedrive\documentos\cientometria_projeto\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\camil\onedrive\documentos\cientometria_projeto\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\camil\onedrive\documentos\cientometria_projeto\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Etapa 2 - Leitura do DataFrame

# %%
df = pd.read_csv(
    'Mestrado_UFABC/BaseG - Graduação/BaseG (1)/BaseG/BaseG---Atuacoes-conselhos-comissoes.csv',
    delimiter='\t',
    engine='python',
    on_bad_lines='skip',
    encoding='utf-8'
)
df
# Out:
#                ID-Lattes                            Nome  \
# 0      '9999283062137312     João Victor Xavier Oliveira
# 1      '9999083750118384  Nelson Alejandro Herrera Gomez
# 2      '9996042179052047         Hadassa Barros de Pieri
# 3      '9996042179052047         Hadassa Barros de Pieri
# 4      '9995648841514038   Ademir Gautério Troina Júnior
# ...                  ...                             ...
# 42010  '0002301188060663           Agatha Bacelar Rabelo
# 42011  '0002301188060663           Agatha Bacelar Rabelo
# 42012  '0002240553309252   Robson Melchiades Neto Junior
# 42013  '0002068151135697             Jeanne Alves Vilela
# 42014  '0002068151135697             Jeanne Alves Vilela
#
#                                              Instituição   Período  \
# 0              Centro Universitário Estácio Juiz de Fora     ATUAL
# 1                                                 ATISAE  ANTERIOR
# 2                              Universidade de São Paulo  ANTERIOR
# 3                              Universidade de São Paulo  ANTERIOR
# 4      Instituto Federal de Educação, Ciência e Tecno...     ATUAL
# ...                                                  ...       ...
# 42010   Prefeitura Municipal de Conceicao do Mato Dentro  ANTERIOR
# 42011   Associação dos Condutores do Patrimônio Cultural     ATUAL
# 42012               Centro Universitário Sagrado Coração  ANTERIOR
# 42013                          Universidade de São Paulo  ANTERIOR
# 42014                          Universidade de São Paulo  ANTERIOR
#
#        Mês-Inicio  Ano-Inicio  Mês-Fim  Ano-Fim  \
# 0             1.0        2024      NaN      NaN
# 1             5.0        2006      7.0   2006.0
# 2            12.0        2022     12.0   2023.0
# 3            12.0        2021     12.0   2022.0
# 4             9.0        2014      NaN      NaN
# ...           ...         ...      ...      ...
# 42010         2.0        2021      6.0   2022.0
# 42011         7.0        2022      NaN      NaN
# 42012         1.0        2020      4.0   2022.0
# 42013        10.0        2018     10.0   2019.0
# 42014         2.0        2016      1.0   2017.0
#
#                                                    Orgão Unidade  \
# 0              Centro Universitário Estácio Juiz de Fora     NaN
# 1                                                 ATISAE     NaN
# 2                        Faculdade de Odontologia da USP     NaN
# 3                        Faculdade de Odontologia da USP     NaN
# 4                             IFRS - Campus Porto Alegre     NaN
# ...                                                  ...     ...
# 42010  Secretaria Municipal de Cultura e Patrimônio H...     NaN
# 42011   Associação dos Condutores do Patrimônio Cultural     NaN
# 42012               Centro de Ciências Exatas e Naturais     NaN
# 42013  Instituto de Arquitetura e Urbanismo da USP/Sã...     NaN
# 42014            Conselho Gestor do Campus de São Carlos     NaN
#
#                                            Especificação
# 0      Atuo na Equipe de Comunicação do Centro Univer...
# 1                   Capacitaçao em Metrologia Industrial
# 2      Suplente do cargo de Representante Discente do...
# 3      Representante discente titular da Comissão de ...
# 4      Presidência da Comissão Especial de Licitação ...
# ...                                                  ...
# 42010  Conselheira Titular do Conselho Municipal de E...
# 42011                  Consultora em Patrimônio Cultural
# 42012                             Representante Discente
# 42013  Representante discente suplente na Comissão de...
# 42014  Representante discente na Comissão incumbida p...
#
# [42015 rows x 11 columns]

# %% [markdown]
# ## Etapa 3 – Visualização geral do DataFrame

# %%
df.columns
# Out:
# Index(['ID-Lattes', 'Nome', 'Instituição', 'Período', 'Mês-Inicio',
#        'Ano-Inicio', 'Mês-Fim', 'Ano-Fim', 'Orgão', 'Unidade',
#        'Especificação'],
#       dtype='object')

# %%
df.dtypes
# Out:
# ID-Lattes         object
# Nome              object
# Instituição       object
# Período           object
# Mês-Inicio       float64
# Ano-Inicio         int64
# Mês-Fim          float64
# Ano-Fim          float64
# Orgão             object
# Unidade           object
# Especificação     object
# dtype: object

# %%
df.shape
# Out:
# (42015, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42015 entries, 0 to 42014
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID-Lattes      42015 non-null  object
#  1   Nome           42015 non-null  object
#  2   Instituição    42010 non-null  object
#  3   Período        42015 non-null  object
#  4   Mês-Inicio     38526 non-null  float64
#  5   Ano-Inicio     42015 non-null  int64
#  6   Mês-Fim        28573 non-null  float64
#  7   Ano-Fim        31271 non-null  float64
#  8   Orgão          40188 non-null  object
#  9   Unidade        7057 non-null   object
#  10  Especificação  42015 non-null  object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 3.5+ MB

# %% [markdown]
# ## Etapa 4 – Verificação de dados ausentes/duplicados & tratamento

# %%
missing_count_per_column = df.isnull().sum()

# %%
missing_percentage_per_column = df.isnull().mean() * 100
missing_percentage_per_column = missing_percentage_per_column.sort_values(ascending=False)

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=missing_percentage_per_column.index, y=missing_percentage_per_column.values)
plt.xticks(rotation=45)
plt.xlabel('Colunas')
plt.ylabel('Percentual de Dados Ausentes')
plt.title('Percentual de Dados Ausentes por Coluna')
plt.show()

# %%
missing_stats = df.isnull().agg(['sum', 'mean'])
missing_stats
# Out:
#       ID-Lattes  Nome  Instituição  Período   Mês-Inicio  Ano-Inicio  \
# sum         0.0   0.0     5.000000      0.0  3489.000000         0.0
# mean        0.0   0.0     0.000119      0.0     0.083042         0.0
#
#            Mês-Fim       Ano-Fim        Orgão       Unidade  Especificação
# sum   13442.000000  10744.000000  1827.000000  34958.000000            0.0
# mean      0.319933      0.255718     0.043484      0.832036            0.0

# %%
lista_orgao = df['Orgão'].value_counts().reset_index()
lista_orgao.columns = ['Orgão', 'contagem']

# %%
lista_orgao.head(50)
# Out:
#                                                 Orgão  contagem
# 0                                            Reitoria      1018
# 1                              Conselho Universitário       455
# 2                               Faculdade de Medicina       328
# 3       UNIVERSIDADE FEDERAL DE SANTA CATARINA - UFSC       302
# 4                   Faculdade de Medicina de Botucatu       275
# 5                         Centro de Ciências da Saúde       199
# 6             Conselho de Ensino, Pesquisa e Extensão       134
# 7                        Faculdade de Medicina do ABC       129
# 8                                Faculdade de Direito       123
# 9                      Faculdade de Ciências de Bauru       119
# 10                                          Diretoria       114
# 11                               Campus Fernandópolis       101
# 12                           Instituto de Biociências        98
# 13             Faculdade de Odontologia de Araraquara        97
# 14  Universidade Federal dos Vales do Jequitinhonh...        90
# 15                   Faculdade de Engenharia de Bauru        88
# 16                                            Privado        87
# 17  Faculdade de Medicina Veterinária e Zootecnia ...        84
# 18           Centro de Ciências Biológicas e da Saúde        83
# 19                      Secretaria Municipal de Saúde        83
# 20  Faculdade de Filosofia e Ciências - Campus de ...        82
# 21  Instituto de Biociências Letras e Ciências Exa...        82
# 22                              Escola de Belas Artes        81
# 23                           Faculdade de Odontologia        78
# 24                                    Diretoria Geral        78
# 25            Faculdade de Medicina de Ribeirão Preto        75
# 26  Universidade Estadual Paulista - Campus de Ilh...        71
# 27                                        Presidência        70
# 28            Faculdade de Ciências e Letras de Assis        70
# 29              Faculdade de Odontologia de Araçatuba        69
# 30  Aeroporto Internacional de Maceió / Zumbi dos ...        68
# 31                               Centro de Tecnologia        67
# 32                     Unidades e Cursos de Graduação        65
# 33  Faculdade de Ciências Farmacêuticas de Araraquara        64
# 34                                        Consultoria        64
# 35                                  Conselho Superior        62
# 36  Instituto Federal Goiano - Campus Avançado Cat...        61
# 37                         Centro de Ciências Médicas        61
# 38  Instituto Federal de Educação Ciência e Tecnol...        61
# 39                                  Curso de Medicina        60
# 40                      Faculdade de Ciências Médicas        59
# 41             Escola de Enfermagem de Ribeirão Preto        59
# 42                     Universidade Estadual Paulista        58
# 43                          Conselho de Administração        58
# 44                          Campus Júlio de Castilhos        58
# 45                    Faculdade de Odontologia da USP        56
# 46   Faculdade de Filosofia Letras e Ciências Humanas        56
# 47                                Instituto de Física        55
# 48                               Instituto de Química        55
# 49           Faculdade de Engenharia de Ilha Solteira        55

# %%
df['Mês-Inicio'] = df['Mês-Inicio'].astype('Int64')
df['Ano-Inicio'] = df['Ano-Inicio'].astype('Int64') 
df['Mês-Fim'] = df['Mês-Fim'].astype('Int64')
df['Mês-Fim'] = df['Mês-Fim'].fillna(0)

df
# Out:
#                ID-Lattes                            Nome  \
# 0      '9999283062137312     João Victor Xavier Oliveira
# 1      '9999083750118384  Nelson Alejandro Herrera Gomez
# 2      '9996042179052047         Hadassa Barros de Pieri
# 3      '9996042179052047         Hadassa Barros de Pieri
# 4      '9995648841514038   Ademir Gautério Troina Júnior
# ...                  ...                             ...
# 42010  '0002301188060663           Agatha Bacelar Rabelo
# 42011  '0002301188060663           Agatha Bacelar Rabelo
# 42012  '0002240553309252   Robson Melchiades Neto Junior
# 42013  '0002068151135697             Jeanne Alves Vilela
# 42014  '0002068151135697             Jeanne Alves Vilela
#
#                                              Instituição   Período  \
# 0              Centro Universitário Estácio Juiz de Fora     ATUAL
# 1                                                 ATISAE  ANTERIOR
# 2                              Universidade de São Paulo  ANTERIOR
# 3                              Universidade de São Paulo  ANTERIOR
# 4      Instituto Federal de Educação, Ciência e Tecno...     ATUAL
# ...                                                  ...       ...
# 42010   Prefeitura Municipal de Conceicao do Mato Dentro  ANTERIOR
# 42011   Associação dos Condutores do Patrimônio Cultural     ATUAL
# 42012               Centro Universitário Sagrado Coração  ANTERIOR
# 42013                          Universidade de São Paulo  ANTERIOR
# 42014                          Universidade de São Paulo  ANTERIOR
#
#        Mês-Inicio  Ano-Inicio  Mês-Fim  Ano-Fim  \
# 0               1        2024        0      NaN
# 1               5        2006        7   2006.0
# 2              12        2022       12   2023.0
# 3              12        2021       12   2022.0
# 4               9        2014        0      NaN
# ...           ...         ...      ...      ...
# 42010           2        2021        6   2022.0
# 42011           7        2022        0      NaN
# 42012           1        2020        4   2022.0
# 42013          10        2018       10   2019.0
# 42014           2        2016        1   2017.0
#
#                                                    Orgão Unidade  \
# 0              Centro Universitário Estácio Juiz de Fora     NaN
# 1                                                 ATISAE     NaN
# 2                        Faculdade de Odontologia da USP     NaN
# 3                        Faculdade de Odontologia da USP     NaN
# 4                             IFRS - Campus Porto Alegre     NaN
# ...                                                  ...     ...
# 42010  Secretaria Municipal de Cultura e Patrimônio H...     NaN
# 42011   Associação dos Condutores do Patrimônio Cultural     NaN
# 42012               Centro de Ciências Exatas e Naturais     NaN
# 42013  Instituto de Arquitetura e Urbanismo da USP/Sã...     NaN
# 42014            Conselho Gestor do Campus de São Carlos     NaN
#
#                                            Especificação
# 0      Atuo na Equipe de Comunicação do Centro Univer...
# 1                   Capacitaçao em Metrologia Industrial
# 2      Suplente do cargo de Representante Discente do...
# 3      Representante discente titular da Comissão de ...
# 4      Presidência da Comissão Especial de Licitação ...
# ...                                                  ...
# 42010  Conselheira Titular do Conselho Municipal de E...
# 42011                  Consultora em Patrimônio Cultural
# 42012                             Representante Discente
# 42013  Representante discente suplente na Comissão de...
# 42014  Representante discente na Comissão incumbida p...
#
# [42015 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42015 entries, 0 to 42014
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID-Lattes      42015 non-null  object
#  1   Nome           42015 non-null  object
#  2   Instituição    42010 non-null  object
#  3   Período        42015 non-null  object
#  4   Mês-Inicio     38526 non-null  Int64
#  5   Ano-Inicio     42015 non-null  Int64
#  6   Mês-Fim        42015 non-null  Int64
#  7   Ano-Fim        31271 non-null  float64
#  8   Orgão          40188 non-null  object
#  9   Unidade        7057 non-null   object
#  10  Especificação  42015 non-null  object
# dtypes: Int64(3), float64(1), object(7)
# memory usage: 3.6+ MB

# %%
#Olhando o que é Unidade - Para entender o dado

df[df['Unidade'].notna()]
# Out:
#                ID-Lattes                                              Nome  \
# 20     '9994633460606425                             Clara de Andrade Leal
# 21     '9994439590825541                 Augusto César Temóteo de Oliveira
# 29     '9991220042082437                       Luana da Silva Sodré Freire
# 39     '9986541135428283                      Hugo Tubal Schmitz Braibante
# 44     '9986294910887187                              Ricardo Fajardo Cury
# ...                  ...                                               ...
# 41976  '0010815421313823               Carlos Felipe de Almeida Cavalcante
# 41989  '0005636017478997                     Tito Cardoso De Almeida Mafra
# 41990  '0005232969944575                            Tatiana Dalcin Meneses
# 41991  '0005232969944575                            Tatiana Dalcin Meneses
# 41992  '0004887636240460  Maria Celeste de Oliveira Pinto Ferreira Esteves
#
#                                              Instituição   Período  \
# 20                Universidade Federal de Santa Catarina  ANTERIOR
# 21                       Universidade Federal da Paraíba  ANTERIOR
# 29                       Universidade Federal Fluminense  ANTERIOR
# 39                   Universidade Federal de Santa Maria     ATUAL
# 44                           Universidade de Santo Amaro  ANTERIOR
# ...                                                  ...       ...
# 41976                          Governo do Estado do Pará     ATUAL
# 41989  Faculdade Pitágoras De Belo Horizonte - Cidade...  ANTERIOR
# 41990                 Universidade da Região da Campanha     ATUAL
# 41991                 Universidade da Região da Campanha     ATUAL
# 41992                                           Diversos     ATUAL
#
#        Mês-Inicio  Ano-Inicio  Mês-Fim  Ano-Fim  \
# 20              9        2019       10   2021.0
# 21              1        2009        6   2014.0
# 29              1        2018       12   2019.0
# 39             12        2008        0      NaN
# 44           <NA>        1990        0   1996.0
# ...           ...         ...      ...      ...
# 41976           2        2021        0      NaN
# 41989           2        2019       12   2019.0
# 41990           8        2005        0      NaN
# 41991           8        2005        0      NaN
# 41992           2        2001        0      NaN
#
#                                                    Orgão  \
# 20         UNIVERSIDADE FEDERAL DE SANTA CATARINA - UFSC
# 21                                              Reitoria
# 29                            Centro de Ciências Médicas
# 39                                              Reitoria
# 44                                              Reitoria
# ...                                                  ...
# 41976  Secretaria de Estado de Administração Penitenc...
# 41989                                Faculdade Pitágoras
# 41990                                            Privado
# 41991                                            Privado
# 41992                                           Jurídico
#
#                                                  Unidade  \
# 20     Conselho de Representantes de Turma do curso d...
# 21                                    Prefeitura da UFPB
# 29                                 Faculdade de Farmácia
# 39     Comissão de Implantação e Acompanhamento de Pr...
# 44               Conselho de Ensino, Pesquisa e Extensão
# ...                                                  ...
# 41976  Corregedoria Geral Penitenciaria SEAP/PA - CGP...
# 41989             Faculdade Pitágoras - Cidade Acadêmica
# 41990                                           Alegrete
# 41991                                           Alegrete
# 41992                                           Jurídico
#
#                                            Especificação
# 20     Conselheira do Conselho de Representantes de T...
# 21     Membro da Comissão de Licitações da Prefeitura...
# 29     Membro titular do Colegiado de Curso da Faculd...
# 39     avaliação dos projetos pedagógicos e acompanha...
# 44     Médico Coordenador da Liga de Profilaxia e Con...
# ...                                                  ...
# 41976  Membro da Equipe de Diligência, Membro de Comi...
# 41989  Representação Discente da CPA - Comissão Própr...
# 41990                                Responsável Técnica
# 41991            comissão de ética e infecção hospitalar
# 41992                                           Advogada
#
# [7057 rows x 11 columns]

# %%
df[df['ID-Lattes'] == "'9999966395780300"]
# Out:
# Empty DataFrame
# Columns: [ID-Lattes, Nome, Instituição, Período, Mês-Inicio, Ano-Inicio, Mês-Fim, Ano-Fim, Orgão, Unidade, Especificação]
# Index: []
